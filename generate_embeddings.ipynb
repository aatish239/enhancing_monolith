# %%
training_user_data_loc = r"drive/MyDrive/MSUoA/raw_user_data.csv"

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import pandas as pd

import nltk

# Ensure required packages are downloaded
nltk.download('punkt', download_dir='../nltk_data')
nltk.download('punkt_tab', force=True, download_dir='../nltk_data')
nltk.download('stopwords', download_dir='../nltk_data')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.data.path.append('../nltk_data')


users_data = pd.read_csv(training_user_data_loc)
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))
def preprocess_reviews(reviews):
    lemmatized_reviews = []
    for review in reviews:
        tokens = word_tokenize(review)
        tokens = [word.lower() for word in tokens if word.isalpha() and word.lower() not in stop_words]
        lemmatized = [lemmatizer.lemmatize(word) for word in tokens]  # Lemmatization
        lemmatized_reviews.append(' '.join(lemmatized))
    return lemmatized_reviews

users_data['user_reviews'] = users_data['user_reviews'].apply(preprocess_reviews)
users_data.to_csv('users_data_without_bert_text_processed.csv', index=False)
# Out:
# [nltk_data] Downloading package punkt to ../nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to ../nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to ../nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
from transformers import BertTokenizer, BertModel
import torch
import ast

users_data = pd.read_csv('users_data_without_bert_text_processed.csv', index_col=0)

# BERT Embeddings
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = BertModel.from_pretrained('bert-base-uncased')

def get_bert_embeddings(reviews):
    inputs = tokenizer(reviews, return_tensors='pt', padding=True, truncation=True)
    with torch.no_grad():
        outputs = bert_model(**inputs)
    cls_embeddings = outputs.last_hidden_state[:, 0, :]  # Shape: [batch_size, 768]
    # Average if multiple embeddings exist
    if cls_embeddings.shape[0] > 1:
        return torch.mean(cls_embeddings, dim=0)  # Shape: [768]
    else:
        return cls_embeddings.squeeze(0)  # Shape: [768]


# Iterating over rows
train_data_with_embeddings = pd.DataFrame(columns=users_data.columns)
train_data_with_embeddings.to_csv('users_data_bert_embeddings.csv', header=True)
batch_data = []
batch_size = 10
for index, row in users_data.iterrows():
    user_reviews = row['user_reviews']
    embedding = get_bert_embeddings(user_reviews)
    row_copy = row.copy()
    row_copy['user_reviews'] = embedding
    print(f"Index: {index}, row {row_copy}")
    batch_data.append(row_copy)
    if (index + 1) % batch_size == 0:
        batch_df = pd.DataFrame(batch_data)
        batch_df.to_csv('users_data_bert_embeddings.csv', mode='a', header=False)
        batch_data = []  # Clear memory
# Out:
# Index: 0, row user_id                                                 ur0000006
# movie_ids                                           ['tt0048613']
# user_ratings                                                 [10]
# user_reviews    [tensor(-0.0130), tensor(0.8864), tensor(0.553...
# Name: 0, dtype: object
# Index: 1, row user_id                                                 ur0000011
# movie_ids       ['tt0029712', 'tt0030337', 'tt0031270', 'tt003...
# user_ratings               [6, 10, 6, 5, 7, 6, 6, 6, 4, 5, 7, 10]
# user_reviews    [tensor(-0.0104), tensor(0.9601), tensor(0.410...
# Name: 1, dtype: object
# Index: 2, row user_id                                                 ur0000157
# movie_ids       ['tt0050480', 'tt0054911', 'tt0057273', 'tt005...
# user_ratings                                     [4, 10, 4, 7, 7]
# user_reviews    [tensor(0.0305), tensor(0.9307), tensor(0.4076...
# Name: 2, dtype: object
# Index: 3, row user_id                                                 ur0000206
# movie_ids                                           ['tt0062283']
# user_ratings                                                 [10]
# user_reviews    [tensor(0.0401), tensor(0.9423), tensor(0.4245...
# Name: 3, dtype: object
# Index: 4, row user_id                                                 ur0000457
# movie_ids                                           ['tt0054941']
# user_ratings                                                  [9]
# user_reviews    [tensor(-0.0794), tensor(0.9496), tensor(0.444...
# Name: 4, dtype: object
# Index: 5, row user_id                                                 ur0000578
# movie_ids       ['tt0024433', 'tt0025417', 'tt0038973', 'tt004...
# user_ratings                                      [8, 5, 2, 4, 1]
# user_reviews    [tensor(-0.0276), tensor(0.9357), tensor(0.402...
# Name: 5, dtype: object
# Index: 6, row user_id                                                 ur0000684
# movie_ids       ['tt0042380', 'tt0044409', 'tt0052411', 'tt005...
# user_ratings                         [5, 8, 7, 8, 7, 10, 8, 5, 6]
# user_reviews    [tensor(0.0181), tensor(0.8694), tensor(0.5173...
# Name: 6, dtype: object
# Index: 7, row user_id                                                 ur0000685
# movie_ids                 ['tt0062979', 'tt0066482', 'tt0068688']
# user_ratings                                            [6, 7, 8]
# user_reviews    [tensor(-0.0099), tensor(0.9480), tensor(0.419...
# Name: 7, dtype: object
# Index: 8, row user_id                                                 ur0000988
# movie_ids                                           ['tt0064674']
# user_ratings                                                  [3]
# user_reviews    [tensor(0.0202), tensor(0.9077), tensor(0.4060...
# Name: 8, dtype: object
# Index: 9, row user_id                                                 ur0001054
# movie_ids                                           ['tt0060396']
# user_ratings                                                  [7]
# user_reviews    [tensor(-0.0096), tensor(0.9017), tensor(0.525...
# Name: 9, dtype: object
# Index: 10, row user_id                                                 ur0001107
# movie_ids       ['tt0041545', 'tt0051845', 'tt0054198', 'tt006...
# user_ratings                                         [6, 8, 7, 1]
# user_reviews    [tensor(-0.0097), tensor(0.9717), tensor(0.431...
# Name: 10, dtype: object
# Index: 11, row user_id                                                 ur0001220
# movie_ids       ['tt0020253', 'tt0020703', 'tt0020793', 'tt002...
# user_ratings    [7, 7, 9, 7, 4, 8, 7, 4, 6, 6, 6, 7, 5, 6, 7, ...
# user_reviews    [tensor(0.0103), tensor(0.9619), tensor(0.3940...
# Name: 11, dtype: object
# Index: 12, row user_id                                                 ur0001326
# movie_ids                                           ['tt0041428']
# user_ratings                                                  [7]
# user_reviews    [tensor(-0.0644), tensor(0.9570), tensor(0.380...
# Name: 12, dtype: object
# Index: 13, row user_id                                                 ur0001478
# movie_ids                                           ['tt0020298']
# user_ratings                                                  [8]
# user_reviews    [tensor(-0.0105), tensor(0.9108), tensor(0.591...
# Name: 13, dtype: object
# Index: 14, row user_id                                                 ur0001586
# movie_ids       ['tt0049063', 'tt0053428', 'tt0056209', 'tt005...
# user_ratings                                         [5, 6, 7, 9]
# user_reviews    [tensor(-0.0532), tensor(0.9953), tensor(0.385...
# Name: 14, dtype: object
# Index: 15, row user_id                                                 ur0001593
# movie_ids                                           ['tt0026421']
# user_ratings                                                  [9]
# user_reviews    [tensor(0.0222), tensor(0.9590), tensor(0.4337...
# Name: 15, dtype: object
# Index: 16, row user_id                                                 ur0001721
# movie_ids                                           ['tt0063057']
# user_ratings                                                  [4]
# user_reviews    [tensor(-0.0392), tensor(0.9643), tensor(0.464...
# Name: 16, dtype: object
# Index: 17, row user_id                                                 ur0001757
# movie_ids                 ['tt0040669', 'tt0059909', 'tt0066858']
# user_ratings                                           [7, 5, 10]
# user_reviews    [tensor(-0.0498), tensor(0.9762), tensor(0.386...
# Name: 17, dtype: object
# Index: 18, row user_id                                                 ur0002216
# movie_ids                 ['tt0047470', 'tt0048256', 'tt0056293']
# user_ratings                                            [5, 2, 1]
# user_reviews    [tensor(0.0443), tensor(0.9436), tensor(0.3861...
# Name: 18, dtype: object
# Index: 19, row user_id                                                 ur0002369
# movie_ids                 ['tt0029222', 'tt0050650', 'tt0058294']
# user_ratings                                            [9, 7, 7]
# user_reviews    [tensor(-0.0342), tensor(0.9735), tensor(0.403...
# Name: 19, dtype: object
